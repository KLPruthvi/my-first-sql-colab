# %% [markdown]
# <a href="https://colab.research.google.com/github/KLPruthvi/my-first-sql-colab/blob/main/SQL_on_3_pt_percentages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd # We'll use pandas to display query results nicely

# Connect to an in-memory SQLite database
# The database will be created in memory and will exist as long as the Colab session is active.
conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

print("Connected to SQLite (in-memory) database successfully!")

# Helper function to run queries and display results
def run_query(query):
    try:
        cursor.execute(query)
        # If it's a SELECT query, fetch and display results
        if query.strip().upper().startswith('SELECT'):
            columns = [description[0] for description in cursor.description]
            results = cursor.fetchall()
            if results:
                df = pd.DataFrame(results, columns=columns)
                display(df) # Using display for richer output in Colab
            else:
                print("Query executed, but no rows returned (e.g., for INSERT, UPDATE, DELETE).")
        else:
            conn.commit() # Commit changes for non-SELECT queries (INSERT, UPDATE, DELETE)
            print("Query executed successfully.")
    except sqlite3.Error as e:
        print(f"An error occurred: {e}")
# Out:
# Connected to SQLite (in-memory) database successfully!

# %%
# Create a Sales table
run_query("""
CREATE TABLE Sales (
    OrderID INTEGER PRIMARY KEY,
    ProductSold TEXT,
    Quantity INTEGER,
    PricePerUnit REAL,
    SaleDate TEXT,
    Region TEXT
);
""")

# Insert some sample data into the Sales table
run_query("""
INSERT INTO Sales (OrderID, ProductSold, Quantity, PricePerUnit, SaleDate, Region) VALUES
(1, 'Laptop', 1, 1200.00, '2024-01-05', 'East'),
(2, 'Mouse', 5, 25.00, '2024-01-05', 'West'),
(3, 'Keyboard', 2, 75.00, '2024-01-06', 'Central'),
(4, 'Monitor', 1, 300.00, '2024-01-06', 'East'),
(5, 'Webcam', NULL, 50.00, '2024-01-07', 'West'), -- Missing Quantity
(6, 'Headphones', 3, -45.00, '2024-01-07', 'Central'), -- Negative Price
(7, 'Laptop', 1, 1200.00, '2024-01-08', 'East'),
(8, 'Mouse', 2, 25.00, '2024-01-08', NULL), -- Missing Region
(9, NULL, 1, 10.00, '2024-01-09', 'West'), -- Missing ProductSold
(10, 'Speaker', 1, 150.00, '2024-01-09', 'North');
""")

print("Sales table created and populated with sample data.")

# Let's view all the data to see what we're working with
print("\nHere's the initial raw data in the Sales table:")
run_query("SELECT * FROM Sales;")
# Out:
# Query executed successfully.
# Query executed successfully.
# Sales table created and populated with sample data.
#
# Here's the initial raw data in the Sales table:
#    OrderID ProductSold  Quantity  PricePerUnit    SaleDate   Region
# 0        1      Laptop       1.0        1200.0  2024-01-05     East
# 1        2       Mouse       5.0          25.0  2024-01-05     West
# 2        3    Keyboard       2.0          75.0  2024-01-06  Central
# 3        4     Monitor       1.0         300.0  2024-01-06     East
# 4        5      Webcam       NaN          50.0  2024-01-07     West
# 5        6  Headphones       3.0         -45.0  2024-01-07  Central
# 6        7      Laptop       1.0        1200.0  2024-01-08     East
# 7        8       Mouse       2.0          25.0  2024-01-08     None
# 8        9        None       1.0          10.0  2024-01-09     West
# 9       10     Speaker       1.0         150.0  2024-01-09    North

# %% [markdown]
# Python

# %%
print("Here's the data currently in your Sales table:")
run_query("SELECT * FROM Sales;")
# Out:
# Here's the data currently in your Sales table:
#    OrderID ProductSold  Quantity  PricePerUnit    SaleDate   Region
# 0        1      Laptop       1.0        1200.0  2024-01-05     East
# 1        2       Mouse       5.0          25.0  2024-01-05     West
# 2        3    Keyboard       2.0          75.0  2024-01-06  Central
# 3        4     Monitor       1.0         300.0  2024-01-06     East
# 4        5      Webcam       NaN          50.0  2024-01-07     West
# 5        6  Headphones       3.0         -45.0  2024-01-07  Central
# 6        7      Laptop       1.0        1200.0  2024-01-08     East
# 7        8       Mouse       2.0          25.0  2024-01-08     None
# 8        9        None       1.0          10.0  2024-01-09     West
# 9       10     Speaker       1.0         150.0  2024-01-09    North

# %%
run_query("INSERT INTO Sales(OrderID, ProductSold, Quantity, PricePerUnit, SaleDate, Region) VALUES (11,'Tablet',2,250,'2024-01-10','North');")
print("Sales after adding")
run_query("SELECT * FROM Sales;")
# Out:
# An error occurred: UNIQUE constraint failed: Sales.OrderID
# Sales after adding
#     OrderID ProductSold  Quantity  PricePerUnit    SaleDate   Region
# 0         1      Laptop       1.0        1200.0  2024-01-05     East
# 1         2       Mouse       5.0          25.0  2024-01-05     West
# 2         3    Keyboard       2.0          75.0  2024-01-06  Central
# 3         4     Monitor       1.0         300.0  2024-01-06     East
# 4         5      Webcam       NaN          50.0  2024-01-07     West
# 5         6  Headphones       3.0         -45.0  2024-01-07  Central
# 6         7      Laptop       1.0        1200.0  2024-01-08     East
# 7         8       Mouse       2.0          25.0  2024-01-08     None
# 8         9        None       1.0          10.0  2024-01-09     West
# 9        10     Speaker       1.0         150.0  2024-01-09    North
# 10       11      Tablet       2.0         250.0  2024-01-10    North

# %%
run_query("UPDATE Sales SET PricePerUnit = 45.00 WHERE OrderID = 6")
run_query ("SELECT * FROM Sales;")
# Out:
# Query executed successfully.
#     OrderID ProductSold  Quantity  PricePerUnit    SaleDate   Region
# 0         1      Laptop       1.0        1200.0  2024-01-05     East
# 1         2       Mouse       5.0          25.0  2024-01-05     West
# 2         3    Keyboard       2.0          75.0  2024-01-06  Central
# 3         4     Monitor       1.0         300.0  2024-01-06     East
# 4         5      Webcam       NaN          50.0  2024-01-07     West
# 5         6  Headphones       3.0          45.0  2024-01-07  Central
# 6         7      Laptop       1.0        1200.0  2024-01-08     East
# 7         8       Mouse       2.0          25.0  2024-01-08     None
# 8         9        None       1.0          10.0  2024-01-09     West
# 9        10     Speaker       1.0         150.0  2024-01-09    North
# 10       11      Tablet       2.0         250.0  2024-01-10    North

# %%
run_query ("DELETE FROM Sales WHERE OrderID = 9")
run_query ("SELECT * FROM Sales;")
# Out:
# Query executed successfully.
#    OrderID ProductSold  Quantity  PricePerUnit    SaleDate   Region
# 0        1      Laptop       1.0        1200.0  2024-01-05     East
# 1        2       Mouse       5.0          25.0  2024-01-05     West
# 2        3    Keyboard       2.0          75.0  2024-01-06  Central
# 3        4     Monitor       1.0         300.0  2024-01-06     East
# 4        5      Webcam       NaN          50.0  2024-01-07     West
# 5        6  Headphones       3.0          45.0  2024-01-07  Central
# 6        7      Laptop       1.0        1200.0  2024-01-08     East
# 7        8       Mouse       2.0          25.0  2024-01-08     None
# 8       10     Speaker       1.0         150.0  2024-01-09    North
# 9       11      Tablet       2.0         250.0  2024-01-10    North

# %%
import pandas as pd
csv_file_name='Player Totals.csv'
try:
    df = pd.read_csv(csv_file_name)
    print(f"'{csv_file_name}' loaded into Pandas DataFrame successfully.")
    print("\nFirst 5 rows of the DataFrame:")
    display(df.head()) # Use display() for nicer output in Colab
except FileNotFoundError:
    print(f"Error: The file '{csv_file_name}' was not found. Did you upload it correctly?")
except Exception as e:
    print(f"An error occurred while reading the CSV: {e}")
# Out:
# 'Player Totals.csv' loaded into Pandas DataFrame successfully.
#
# First 5 rows of the DataFrame:
#    seas_id  season  player_id       player  birth_year pos   age  experience  \
# 0  31871.0    2025     5025.0   A.J. Green         NaN  SG  25.0           3
# 1  31872.0    2025     5026.0  A.J. Lawson         NaN  SG  24.0           3
# 2  31873.0    2025     5210.0   AJ Johnson         NaN  SG  20.0           1
# 3  31874.0    2025     5210.0   AJ Johnson         NaN  SG  20.0           1
# 4  31875.0    2025     5210.0   AJ Johnson         NaN  SG  20.0           1
#
#     lg   tm  ...  ft_percent   orb    drb    trb  ast   stl  blk   tov   pf  \
# 0  NBA  MIL  ...       0.815  18.0  156.0  174.0  108  37.0  7.0  40.0  157
# 1  NBA  TOR  ...       0.683  20.0   66.0   86.0   31  13.0  6.0  15.0   44
# 2  NBA  TOT  ...       0.865   8.0   51.0   59.0   76  12.0  3.0  35.0   50
# 3  NBA  MIL  ...       0.500   0.0    7.0    7.0    7   1.0  0.0   4.0    0
# ...

# %%
import pandas as pd
import sqlite3

# Re-establish connection if the Colab session restarted, or if this is a new notebook
try:
    if 'conn' not in globals() or conn is None:
        conn = sqlite3.connect(':memory:')
        cursor = conn.cursor()
        print("Re-established SQLite (in-memory) database connection.")
except sqlite3.Error as e:
    print(f"Error re-establishing connection: {e}")

csv_file_name = 'Player Totals.csv'

try:
    df = pd.read_csv(csv_file_name)
    print(f"'{csv_file_name}' loaded into Pandas DataFrame successfully.")

    df.columns = df.columns.str.replace(' ', '_').str.replace('[^A-Za-z0-9_]+', '', regex=True)
    print("\nColumn names have been cleaned for SQL compatibility.")

    table_name = 'nba_stats'
    df.to_sql(table_name, conn, if_exists='replace', index=False)
    print(f"\nData successfully loaded into SQLite table: '{table_name}'")

except FileNotFoundError:
    print(f"Error: The file '{csv_file_name}' was not found. Please ensure it's uploaded to Colab's file panel.")
except Exception as e:
    print(f"An unexpected error occurred during data loading: {e}")

print(f"\n--- Verifying data in '{table_name}' using SQL ---")
run_query(f"SELECT COUNT(*) FROM {table_name};")
run_query(f"SELECT * FROM {table_name} LIMIT 5;")
# Out:
# 'Player Totals.csv' loaded into Pandas DataFrame successfully.
#
# Column names have been cleaned for SQL compatibility.
#
# Data successfully loaded into SQLite table: 'nba_stats'
#
# --- Verifying data in 'nba_stats' using SQL ---
#    COUNT(*)
# 0     32605
#    seas_id  season  player_id       player birth_year pos   age  experience  \
# 0  31871.0    2025     5025.0   A.J. Green       None  SG  25.0           3
# 1  31872.0    2025     5026.0  A.J. Lawson       None  SG  24.0           3
# 2  31873.0    2025     5210.0   AJ Johnson       None  SG  20.0           1
# 3  31874.0    2025     5210.0   AJ Johnson       None  SG  20.0           1
# 4  31875.0    2025     5210.0   AJ Johnson       None  SG  20.0           1
#
#     lg   tm  ...  ft_percent   orb    drb    trb  ast   stl  blk   tov   pf  \
# 0  NBA  MIL  ...       0.815  18.0  156.0  174.0  108  37.0  7.0  40.0  157
# 1  NBA  TOR  ...       0.683  20.0   66.0   86.0   31  13.0  6.0  15.0   44
# ...

# %%
run_query("SELECT * FROM nba_stats WHERE pts IS NULL;")
# Out:
# Query executed, but no rows returned (e.g., for INSERT, UPDATE, DELETE).

# %%
# This will print all the column names directly from your DataFrame
print(df.columns.tolist())
# Out:
# ['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age', 'experience', 'lg', 'tm', 'g', 'gs', 'mp', 'fg', 'fga', 'fg_percent', 'x3p', 'x3pa', 'x3p_percent', 'x2p', 'x2pa', 'x2p_percent', 'e_fg_percent', 'ft', 'fta', 'ft_percent', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts']

# %%
run_query("SELECT * FROM nba_stats WHERE x3pa IS NULL;")
# Out:
#       seas_id  season  player_id          player  birth_year  pos   age  \
# 0      7647.0    1979     1548.0     Aaron James         NaN   SF  26.0
# 1      7648.0    1979     1692.0  Adrian Dantley         NaN   SF  23.0
# 2      7649.0    1979     1550.0      Al Skinner      1952.0   SG  26.0
# 3      7650.0    1979     1550.0      Al Skinner      1952.0   SG  26.0
# 4      7651.0    1979     1550.0      Al Skinner      1952.0   SG  26.0
# ...       ...     ...        ...             ...         ...  ...   ...
# 6347    200.0    1947      157.0     Walt Miller         NaN    F  31.0
# 6348    201.0    1947      158.0   Warren Fenley         NaN    F  24.0
# 6349    202.0    1947      159.0   Wilbert Kautz         NaN  G-F  31.0
# 6350    203.0    1947      160.0  Woody Grimshaw         NaN    G  27.0
# 6351    204.0    1947      161.0     Wyndol Gray         NaN  G-F  24.0
#
#       experience   lg   tm  ...  ft_percent    orb    drb    trb  ast   stl  \
# ...

# %%
run_query("SELECT season, player, IFNULL (x3pa, 0) AS total_3pa_analysis, IFNULL (x3p, 0) AS total_3pm_analysis FROM nba_stats LIMIT 50;")
# Out:
#     season             player  total_3pa_analysis  total_3pm_analysis
# 0     2025         A.J. Green               363.0               155.0
# 1     2025        A.J. Lawson               101.0                33.0
# 2     2025         AJ Johnson                90.0                24.0
# 3     2025         AJ Johnson                 5.0                 3.0
# 4     2025         AJ Johnson                85.0                21.0
# 5     2025       Aaron Gordon               172.0                75.0
# 6     2025      Aaron Holiday               181.0                72.0
# 7     2025      Aaron Nesmith               195.0                84.0
# 8     2025      Aaron Wiggins               339.0               130.0
# 9     2025       Adam Flagler                72.0                14.0
# 10    2025       Adama Sanogo                 0.0                 0.0
# 11    2025          Adem Bona                 1.0                 0.0
# ...

# %%
run_query("SELECT MIN(season) AS early_season, MAX(season) AS latest_season FROM nba_stats;")
# Out:
#    early_season  latest_season
# 0          1947           2025

# %%
run_query("SELECT SUM(IFNULL (x3pa, 0))/COUNT(DISTINCT season) AS avg_3pa_season, SUM(IFNULL (x3p, 0))/COUNT(DISTINCT season) AS avg_3pm_season FROM nba_stats WHERE season >= 1980 AND season <=1998;")
# Out:
#    avg_3pa_season  avg_3pm_season
# 0    16782.315789          5607.0

# %%
run_query("SELECT SUM(IFNULL (x3pa, 0))/COUNT(DISTINCT season) AS avg_3pa_season, SUM(IFNULL (x3p, 0))/COUNT(DISTINCT season) AS avg_3pm_season FROM nba_stats WHERE season >= 1980 AND season <=1998;")

# %%
run_query("""
SELECT
          'MJ(1980-1998)' AS era,
          SUM(IFNULL (x3pa, 0)) / COUNT(DISTINCT season) AS avg_3pa_season,
          SUM(IFNULL (x3p, 0)) / COUNT(DISTINCT season) AS avg_3pm_season,
          (CAST(SUM(IFNULL(x3p, 0)) AS REAL)/ SUM(IFNULL(x3pa, 0)))*100 AS avg_3pt
FROM
          nba_stats
WHERE
          season >= 1980 AND season <= 1998

UNION ALL
SELECT
          'Kobe(1999-2012)' AS era,
          SUM(IFNULL (x3pa, 0)) / COUNT(DISTINCT season) AS avg_3pa_season,
          SUM(IFNULL (x3p, 0)) / COUNT(DISTINCT season) AS avg_3pm_season,
          (CAST(SUM(IFNULL(x3p, 0)) AS REAL)/ SUM(IFNULL(x3pa, 0)))*100 AS avg_3pt
FROM
          nba_stats
where
          season >= 1999 AND season <= 2012

UNION All
SELECT
          'LBJ(2004-2016)' AS era,
          SUM(IFNULL (x3pa, 0)) / COUNT(DISTINCT season) AS avg_3pa_season,
          SUM(IFNULL (x3p, 0)) / COUNT(DISTINCT season) AS avg_3pm_season,
          (CAST(SUM(IFNULL(x3p, 0)) AS REAL)/ SUM(IFNULL(x3pa, 0)))*100 AS avg_3pt
FROM
          nba_stats
where
          season >= 2004 AND season <= 2016
UNION All
SELECT
          'Curry(2013-2025)' AS era,
          SUM(IFNULL (x3pa, 0)) / COUNT(DISTINCT season) AS avg_3pa_season,
          SUM(IFNULL (x3p, 0)) / COUNT(DISTINCT season) AS avg_3pm_season,
          (CAST(SUM(IFNULL(x3p, 0)) AS REAL)/ SUM(IFNULL(x3pa, 0)))*100 AS avg_3pt
FROM
          nba_stats
where
          season >= 2013 AND season <= 2025;
          """)
# Out:
#                 era  avg_3pa_season  avg_3pm_season    avg_3pt
# 0     MJ(1980-1998)    16782.315789     5607.000000  33.410169
# 1   Kobe(1999-2012)    40938.357143    14512.857143  35.450512
# 2    LBJ(2004-2016)    49913.923077    17753.000000  35.567230
# 3  Curry(2013-2025)    79798.692308    28572.692308  35.805966
